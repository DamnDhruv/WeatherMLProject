# %%
import pandas as pd

# %%
df = pd.read_csv("weather_dataset.csv")

# %%
df
# Out:
#            City  Temprature  Humidity  Pressure        Condition
# 0      New York       30.04        76      1014    broken clouds
# 1   Los Angeles       24.94        56      1015        clear sky
# 2       Chicago       25.14        62      1017  overcast clouds
# 3       Houston       31.87        58      1017       few clouds
# 4       Phoenix       38.55        25      1012        clear sky
# ..          ...         ...       ...       ...              ...
# 95      Jakarta       27.95        76      1011    moderate rain
# 96     Surabaya       25.56        93      1013        clear sky
# 97      Bandung       26.95        82      1014  overcast clouds
# 98        Medan       23.54        93      1011  overcast clouds
# 99       Bekasi       28.07        78      1011       light rain
#
# [100 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        100 non-null    object
#  1   Temprature  100 non-null    float64
#  2   Humidity    100 non-null    int64
#  3   Pressure    100 non-null    int64
#  4   Condition   100 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ KB

# %%
df["Condition"].value_counts()
# Out:
# Condition
# clear sky           29
# overcast clouds     23
# few clouds          14
# light rain          12
# broken clouds       10
# scattered clouds     7
# moderate rain        4
# extreme rain         1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Condition_encoded"]= le.fit_transform(df['Condition'])
le.classes_
# Out:
# array(['broken clouds', 'clear sky', 'extreme rain', 'few clouds',
#        'light rain', 'moderate rain', 'overcast clouds',
#        'scattered clouds'], dtype=object)

# %%
df["Condition_encoded"]
# Out:
# 0     0
# 1     1
# 2     6
# 3     3
# 4     1
#      ..
# 95    5
# 96    1
# 97    6
# 98    6
# 99    4
# Name: Condition_encoded, Length: 100, dtype: int32

# %%
X = df[["Temprature","Humidity","Pressure"]]
y = df[["Condition_encoded"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
y_train = y_train.ravel()
y_test = y_test.ravel()
print(y_train.shape)          
print(y_train.ravel().shape)
# Out:
# (90,)
# (90,)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
Prediction = clf.predict(X_test)
Prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %%
import numpy as np
unique, counts = np.unique(y_train, return_counts=True)
print("Training set class distribution:", dict(zip(unique, counts)))
# Out:
# Training set class distribution: {0: 7, 1: 28, 2: 1, 3: 14, 4: 10, 5: 4, 6: 19, 7: 7}

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (90, 3)
# y_train shape: (90,)

# %%
print(df[["Temprature", "Humidity", "Pressure"]].describe())
# Out:
#        Temprature    Humidity     Pressure
# count  100.000000  100.000000   100.000000
# mean    23.621800   64.490000  1011.570000
# std      6.823614   21.143805     7.433551
# min      5.980000    8.000000   998.000000
# 25%     18.445000   52.000000  1007.000000
# 50%     24.725000   70.000000  1011.000000
# 75%     28.087500   80.000000  1016.000000
# max     38.680000   98.000000  1032.000000

# %%
import pickle

# %%
pickle.dump(clf,open('Condition_classifier.pkl','wb'))
